# %%
import pandas as pd

df = pd.read_csv("data_split/train_metadata.csv")
print(df.head())
print(df.columns)
# Out:
#    file_path                              normalized_transcript
# 0          0  các cô tiến hành sơ chế chế biến rồi đưa đồ ăn...
# 1          1  và thực hiện các quy định của pháp luật về bảo...
# 2          2  thì việc khơi dậy khát vọng thoát nghèo của ch...
# 3          3  luôn thấy tự tin phát huy sáng tạo tự giác tro...
# 4          4  ki lô gam giúp gia đình chị phát triển kinh tế...
# Index(['file_path', 'normalized_transcript'], dtype='object')

# %%
df = pd.read_csv("data_split/train_metadata.csv")
print(df.iloc[0])
# Out:
# file_path                                                                0
# normalized_transcript    các cô tiến hành sơ chế chế biến rồi đưa đồ ăn...
# Name: 0, dtype: object
